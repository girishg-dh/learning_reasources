# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %%
# from IPython.display import Markdown
# Markdown("./config/agents.yaml")

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)
# Out:
# 2025-08-24 16:05:07,315 - 139722971827072 - __init__.py-__init__:538 - WARNING: Overriding of current TracerProvider is not allowed

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Project Breakdown for Website Development
#
# #### Project Overview:
# The goal of the website project is to create a modern, responsive website for a small business that effectively communicates the brand's values, services, and points of contact.
#
# ### Comprehensive Task List:
#
# 1. **Initial Project Kickoff and Requirement Analysis**
#    - **Scope**: Gather detailed requirements from stakeholders, clarify objectives, and define project scope.
#    - **Deliverables**: Requirement document.
#    - **Duration**: 1 week
#    - **Dependencies**: N/A
#
# 2. **Create Responsive Design**
#    - **Scope**: Design should be mobile-first, ensuring it adapts seamlessly to various screen sizes.
#    - **Deliverables**: Wireframes and mockups for both desktop and mobile views.
#    - **Duration**: 2 weeks
#    - **Dependencies**: Completion of Initial Project Kickoff.
#
# 3. **Develop User Interface (UI)**
#    - **Scope**: Implement a modern design with a clean and visually appealing layout including colors, typography, and branding.
#    - **Deliverables**: Fully designed UI components.
#    - **Duration**: 2 weeks
#    - **Dependencies**: Completion of Responsive Design.
#
# 4. **User-Friendly Navigation System**
#    - **Scope**: Design and implement intuitive menu structure for easy access to information.
#    - **Deliverables**: Navigation mockup and working prototype.
#    - **Duration**: 1 week
#    - **Dependencies**: Completion of UI Design.
#
# 5. **Create "About Us" Page**
#    - **Scope**: Content creation and layout design that highlights the company’s values and history.
#    - **Deliverables**: Finalized "About Us" page.
#    - **Duration**: 1 week
#    - **Dependencies**: Completion of Navigation System.
#
# 6. **Design "Services" Page**
#    - **Scope**: Showcase services with detailed descriptions and visual elements.
#    - **Deliverables**: Finalized "Services" page.
#    - **Duration**: 1 week
#    - **Dependencies**: Completion of "About Us" Page.
#
# 7. **Create "Contact Us" Page**
#    - **Scope**: Include a form for inquiries and an integrated map location.
#    - **Deliverables**: Finalized "Contact Us" page with functional form and map.
#    - **Duration**: 1 week
#    - **Dependencies**: Completion of "Services" Page.
#
# 8. **Blog Section Implementation**
#    - **Scope**: Develop functionality for posting articles, allowing industry news and company updates to be shared.
#    - **Deliverables**: Blog section with initial test posts.
#    - **Duration**: 2 weeks
#    - **Dependencies**: Completion of "Contact Us" Page.
#
# 9. **SEO and Performance Optimization**
#    - **Scope**: Ensure fast loading times and optimize website for search engines.
#    - **Deliverables**: SEO audit report and performance testing results.
#    - **Duration**: 1 week
#    - **Dependencies**: Completion of Blog Section.
#
# 10. **Integration of Social Media Links**
#     - **Scope**: Add social sharing options and link to business profiles.
#     - **Deliverables**: Functional social media integration.
#     - **Duration**: 1 week
#     - **Dependencies**: Completion of "Contact Us" Page.
#
# 11. **Testimonials Section Design**
#     - **Scope**: Create a section for customer testimonials to build trust and credibility.
#     - **Deliverables**: Fully designed testimonials section.
#     - **Duration**: 1 week
#     - **Dependencies**: Completion of "Services" Page.
#
# 12. **Quality Assurance Testing**
#     - **Scope**: Final testing of all pages for functionality, usability, and bugs.
#     - **Deliverables**: QA report with issues documented.
#     - **Duration**: 2 weeks
#     - **Dependencies**: Completion of all previous pages.
#
# 13. **Final Review and Project Launch**
#     - **Scope**: Conduct final walkthrough with stakeholders, implement feedback, and launch the website.
#     - **Deliverables**: Live website.
#     - **Duration**: 1 week
#     - **Dependencies**: Completion of QA Testing.
#
# #### Gantt Chart Visualization:
# *You would typically create a visual Gantt chart using project management software, but here is an ASCII representation for simplicity:*
#
# ```
# Week | Task
# ----------------------------
#   1  | Initial Project Kickoff
#   2  | Create Responsive Design
#   3  | Develop User Interface
#   4  | User-Friendly Navigation System
#   5  | Create "About Us" Page
#   6  | Design "Services" Page
#   7  | Create "Contact Us" Page
#   8  | Blog Section Implementation
#   9  | SEO and Performance Optimization
#   10 | Integration of Social Media Links
#   11 | Testimonials Section Design
#   12 | Quality Assurance Testing
#   13 | Final Review and Project Launch
# ----------------------------
# ```
#
# ### Conclusion
# This project breakdown details each task for the website project with clear deliverables, timelines, and dependencies. This systematic approach ensures comprehensive coverage of all requirements, leading to a successful outcome in delivering a high-quality website for the small business.
#
# ### Team Member Responsibilities:
# - **John Doe (Project Manager)**: Overseeing project timelines, task delegation, and stakeholder communication.
# - **Jane Doe (Software Engineer)**: Implementing website functionality and backend development.
# - **Bob Smith (Designer)**: Creating the visual layout and ensuring an attractive user interface.
# - **Alice Johnson & Tom Brown (QA Engineers)**: Conducting thorough testing for quality assurance.
#
# This meticulous planning will facilitate successful project execution and timely delivery of the website.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Website Project
#
# #### 1. Initial Project Kickoff and Requirement Analysis
# - **Time Required**: 1 week
# - **Resources Needed**: 1 Project Manager, 1 Business Analyst
# - **Effort**: 40 hours
# - **Dependencies**: None
# - **Risks/Uncertainties**: Delays in stakeholder availability may extend timeline.
#
# #### 2. Create Responsive Design
# - **Time Required**: 2 weeks
# - **Resources Needed**: 1 Designer
# - **Effort**: 80 hours
# - **Dependencies**: Completion of Initial Project Kickoff
# - **Risks/Uncertainties**: Potential changes in requirements can impact design.
#
# #### 3. Develop User Interface (UI)
# - **Time Required**: 2 weeks
# - **Resources Needed**: 1 Designer, 1 Software Engineer
# - **Effort**: 80 hours
# - **Dependencies**: Completion of Responsive Design
# - **Risks/Uncertainties**: Complications with implementation of design may arise.
#
# #### 4. User-Friendly Navigation System
# - **Time Required**: 1 week
# - **Resources Needed**: 1 Software Engineer
# - **Effort**: 40 hours
# - **Dependencies**: Completion of UI Design
# - **Risks/Uncertainties**: Misalignment with user expectations as per the design could require revisions.
#
# #### 5. Create "About Us" Page
# - **Time Required**: 1 week
# - **Resources Needed**: 1 Designer, 1 Content Writer
# - **Effort**: 40 hours
# - **Dependencies**: Completion of Navigation System
# - **Risks/Uncertainties**: Content approval delays may extend timeline.
#
# #### 6. Design "Services" Page
# - **Time Required**: 1 week
# - **Resources Needed**: 1 Designer
# - **Effort**: 40 hours
# - **Dependencies**: Completion of "About Us" Page
# - **Risks/Uncertainties**: Feedback on design could require multiple iterations.
#
# #### 7. Create "Contact Us" Page
# - **Time Required**: 1 week
# - **Resources Needed**: 1 Designer, 1 Software Engineer
# - **Effort**: 40 hours
# - **Dependencies**: Completion of "Services" Page
# - **Risks/Uncertainties**: Issues with forms or map integration could delay the task.
#
# #### 8. Blog Section Implementation
# - **Time Required**: 2 weeks
# - **Resources Needed**: 1 Software Engineer
# - **Effort**: 80 hours
# - **Dependencies**: Completion of "Contact Us" Page
# - **Risks/Uncertainties**: Complexity in backend functionality may increase the effort needed.
#
# #### 9. SEO and Performance Optimization
# - **Time Required**: 1 week
# - **Resources Needed**: 1 Software Engineer
# - **Effort**: 40 hours
# - **Dependencies**: Completion of Blog Section
# - **Risks/Uncertainties**: Unexpected performance issues could require additional fixes.
#
# #### 10. Integration of Social Media Links
# - **Time Required**: 1 week
# - **Resources Needed**: 1 Software Engineer
# - **Effort**: 40 hours
# - **Dependencies**: Completion of "Contact Us" Page
# - **Risks/Uncertainties**: Compatibility issues with social media APIs may be encountered.
#
# #### 11. Testimonials Section Design
# - **Time Required**: 1 week
# - **Resources Needed**: 1 Designer
# - **Effort**: 40 hours
# - **Dependencies**: Completion of "Services" Page
# - **Risks/Uncertainties**: Client dissatisfaction with design may necessitate revisions.
#
# #### 12. Quality Assurance Testing
# - **Time Required**: 2 weeks
# - **Resources Needed**: 2 QA Engineers
# - **Effort**: 160 hours (80 hours each)
# - **Dependencies**: Completion of all previous pages
# - **Risks/Uncertainties**: Finding critical bugs could extend the testing period.
#
# #### 13. Final Review and Project Launch
# - **Time Required**: 1 week
# - **Resources Needed**: 1 Project Manager, 1 Software Engineer, 1 Designer, 2 QA Engineers
# - **Effort**: 40 hours
# - **Dependencies**: Completion of QA Testing
# - **Risks/Uncertainties**: Feedback from stakeholders could lead to rework before launch.
#
# ### Summary of Project Timeline and Resources
#
# | Task                                     | Duration | Team Members Involved |
# |------------------------------------------|----------|-----------------------|
# | Initial Project Kickoff                 | 1 week  | 1 Project Manager, 1 Business Analyst |
# | Create Responsive Design                 | 2 weeks | 1 Designer            |
# | Develop User Interface                   | 2 weeks | 1 Designer, 1 Software Engineer |
# | User-Friendly Navigation System          | 1 week  | 1 Software Engineer    |
# | Create "About Us" Page                  | 1 week  | 1 Designer, 1 Content Writer |
# | Design "Services" Page                   | 1 week  | 1 Designer             |
# | Create "Contact Us" Page                | 1 week  | 1 Designer, 1 Software Engineer |
# | Blog Section Implementation              | 2 weeks | 1 Software Engineer     |
# | SEO and Performance Optimization         | 1 week  | 1 Software Engineer     |
# | Integration of Social Media Links        | 1 week  | 1 Software Engineer     |
# | Testimonials Section Design              | 1 week  | 1 Designer             |
# | Quality Assurance Testing                | 2 weeks | 2 QA Engineers         |
# | Final Review and Project Launch         | 1 week  | 1 Project Manager, 1 Software Engineer, 1 Designer, 2 QA Engineers |
#
# ### Total Project Duration
# - **Overall Duration**: 13 weeks
#
# ### Overall Risks and Uncertainties
# - Stakeholder engagement and timely feedback.
# - Potential changes in project requirements leading to scope creep.
# - Availability of resources during critical phases could impact timelines.
#
# This estimation report aims to provide a comprehensive view of the time, resources, and effort required to successfully deliver the website project. The identified risks should be closely monitored throughout the project lifecycle to ensure timely delivery within the budget.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for the Website Project
#
# | Task                                     | Assigned Team Members              | Start Date   | End Date     |
# |------------------------------------------|-----------------------------------|--------------|--------------|
# | Initial Project Kickoff                 | John Doe                          | Week 1       | Week 1       |
# | Create Responsive Design                 | Bob Smith                         | Week 2       | Week 3       |
# | Develop User Interface                   | Jane Doe, Bob Smith               | Week 4       | Week 5       |
# | User-Friendly Navigation System          | Jane Doe                          | Week 6       | Week 6       |
# | Create "About Us" Page                  | Bob Smith                         | Week 7       | Week 7       |
# | Design "Services" Page                   | Bob Smith                         | Week 8       | Week 8       |
# | Create "Contact Us" Page                | Jane Doe, Bob Smith               | Week 9       | Week 9       |
# | Blog Section Implementation              | Jane Doe                          | Week 10      | Week 11      |
# | SEO and Performance Optimization         | Jane Doe                          | Week 12      | Week 12      |
# | Integration of Social Media Links        | Jane Doe                          | Week 13      | Week 13      |
# | Testimonials Section Design              | Bob Smith                         | Week 8       | Week 8       |
# | Quality Assurance Testing                | Alice Johnson, Tom Brown          | Week 12      | Week 13      |
# | Final Review and Project Launch         | John Doe, Jane Doe, Bob Smith, Alice Johnson, Tom Brown | Week 13 | Week 13 |
#
# ### Summary of Allocation Decisions:
#
# 1. **Initial Project Kickoff**:
#    - John Doe (Project Manager) is assigned as the sole resource due to his leadership role, ensuring project alignment and stakeholder communication is prioritized.
#
# 2. **Create Responsive Design**:
#    - Bob Smith (Designer) handles this task alone. His specialized design skills are required here, and ensuring he focuses fully on this task helps mitigate any potential risks related to design changes.
#
# 3. **Develop User Interface (UI)**:
#    - This task involves both Jane Doe (Software Engineer) and Bob Smith (Designer) to effectively integrate design and technical implementation. Their collaboration will reduce the likelihood of misalignment.
#
# 4. **User-Friendly Navigation System**:
#    - Assigned solely to Jane Doe, allowing her to utilize her engineering skills to create a seamless navigation experience after the UI is designed.
#
# 5. **Create "About Us" Page**:
#    - Bob Smith is assigned again, as it requires his design expertise, fitting naturally with his ongoing involvement in the design aspects of the project.
#
# 6. **Design "Services" Page**:
#    - Again, Bob Smith takes the lead to maintain continuity in the design process, ensuring a coherent style across all pages.
#
# 7. **Create "Contact Us" Page**:
#    - This task involves both Jane Doe and Bob Smith, as it requires functionality (by Jane) and the design (by Bob) of contact forms, which necessitates teamwork.
#
# 8. **Blog Section Implementation**:
#    - Jane Doe (Software Engineer) is assigned this task independently, allowing her to focus on backend functionality without interruption from other design tasks.
#
# 9. **SEO and Performance Optimization**:
#    - Another solo task for Jane Doe, capitalizing on her technical skills post-implementation to ensure the website is optimized before launch.
#
# 10. **Integration of Social Media Links**:
#     - Jane Doe is assigned this final enhancement after the key pages are complete, which complements her previous work and is critical for user engagement.
#
# 11. **Testimonials Section Design**:
#     - This is again assigned to Bob Smith, who should focus on designs that resonate with the established site aesthetic.
#
# 12. **Quality Assurance Testing**:
#     - Alice Johnson and Tom Brown (QA Engineers) are paired as they complement each other's expertise for thorough testing across all pages and features.
#
# 13. **Final Review and Project Launch**:
#     - This task involves John Doe, Jane Doe, Bob Smith, Alice Johnson, and Tom Brown to ensure comprehensive oversight, technical checks, and design alignment before launching the project.
#
# ### Conclusion:
# This strategic allocation allows for optimized use of each team member's strengths while preventing overload. Each member is actively engaged without being overburdened, and overlaps in critical areas allow for robust collaboration. The timeline extends over 13 weeks, with careful attention to dependencies and risks, facilitating a smoother project execution strategy.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0030
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         20040          12122               7918                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Initial Project Kickoff',
#    'estimated_time_hours': 1.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Create Responsive Design',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Develop User Interface',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe', 'Bob Smith']},
#   {'task_name': 'User-Friendly Navigation System',
#    'estimated_time_hours': 10.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create "About Us" Page',
#    'estimated_time_hours': 5.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Design "Services" Page',
#    'estimated_time_hours': 5.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Create "Contact Us" Page',
#    'estimated_time_hours': 5.0,
#    'required_resources': ['Jane Doe', 'Bob Smith']},
#   {'task_name': 'Blog Section Implementation',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'SEO and Performance Optimization',
#    'estimated_time_hours': 10.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Integration of Social Media Links',
#    'estimated_time_hours': 5.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Testimonials Section Design',
#    'estimated_time_hours': 5.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Quality Assurance Testing',
#    'estimated_time_hours': 30.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Final Review and Project Launch',
#    'estimated_time_hours': 10.0,
#    'required_resources': ['John Doe',
#     'Jane Doe',
#     'Bob Smith',
#     'Alice Johnson',
#     'Tom Brown']}],
#  'milestones': [{'milestone_name': 'Project Kickoff and Design Phase',
#    'tasks': ['Initial Project Kickoff',
#     'Create Responsive Design',
#     'Develop User Interface',
#     'User-Friendly Navigation System',
#     'Create "About Us" Page',
#     'Design "Services" Page']},
#   {'milestone_name': 'Content Creation and Implementation',
#    'tasks': ['Create "Contact Us" Page',
#     'Blog Section Implementation',
#     'Testimonials Section Design']},
#   {'milestone_name': 'Testing and Launch',
#    'tasks': ['Quality Assurance Testing',
#     'SEO and Performance Optimization',
#     'Integration of Social Media Links',
#     'Final Review and Project Launch']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)
df_tasks['estimated_time_hours'] = df_tasks['estimated_time_hours'].apply(lambda x: round(x))

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_7710a th {
#   font-size: 120%;
# }
# #T_7710a  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_7710a" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7710a_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_7710a_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_7710a_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7710a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7710a_row0_col0" class="data row0 col0" >Initial Project Kickoff</td>
#       <td id="T_7710a_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_7710a_row0_col2" class="data row0 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7710a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7710a_row1_col0" class="data row1 col0" >Create Responsive Design</td>
#       <td id="T_7710a_row1_col1" class="data row1 col1" >20</td>
#       <td id="T_7710a_row1_col2" class="data row1 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_7710a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7710a_row2_col0" class="data row2 col0" >Develop User Interface</td>
#       <td id="T_7710a_row2_col1" class="data row2 col1" >40</td>
#       <td id="T_7710a_row2_col2" class="data row2 col2" >['Jane Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_7710a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7710a_row3_col0" class="data row3 col0" >User-Friendly Navigation System</td>
#       <td id="T_7710a_row3_col1" class="data row3 col1" >10</td>
#       <td id="T_7710a_row3_col2" class="data row3 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7710a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7710a_row4_col0" class="data row4 col0" >Create "About Us" Page</td>
#       <td id="T_7710a_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_7710a_row4_col2" class="data row4 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_7710a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7710a_row5_col0" class="data row5 col0" >Design "Services" Page</td>
#       <td id="T_7710a_row5_col1" class="data row5 col1" >5</td>
#       <td id="T_7710a_row5_col2" class="data row5 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_7710a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7710a_row6_col0" class="data row6 col0" >Create "Contact Us" Page</td>
#       <td id="T_7710a_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_7710a_row6_col2" class="data row6 col2" >['Jane Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_7710a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7710a_row7_col0" class="data row7 col0" >Blog Section Implementation</td>
#       <td id="T_7710a_row7_col1" class="data row7 col1" >20</td>
#       <td id="T_7710a_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7710a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7710a_row8_col0" class="data row8 col0" >SEO and Performance Optimization</td>
#       <td id="T_7710a_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_7710a_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7710a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7710a_row9_col0" class="data row9 col0" >Integration of Social Media Links</td>
#       <td id="T_7710a_row9_col1" class="data row9 col1" >5</td>
#       <td id="T_7710a_row9_col2" class="data row9 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_7710a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7710a_row10_col0" class="data row10 col0" >Testimonials Section Design</td>
#       <td id="T_7710a_row10_col1" class="data row10 col1" >5</td>
#       <td id="T_7710a_row10_col2" class="data row10 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_7710a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7710a_row11_col0" class="data row11 col0" >Quality Assurance Testing</td>
#       <td id="T_7710a_row11_col1" class="data row11 col1" >30</td>
#       <td id="T_7710a_row11_col2" class="data row11 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_7710a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7710a_row12_col0" class="data row12 col0" >Final Review and Project Launch</td>
#       <td id="T_7710a_row12_col1" class="data row12 col1" >10</td>
#       <td id="T_7710a_row12_col2" class="data row12 col2" >['John Doe', 'Jane Doe', 'Bob Smith', 'Alice Johnson', 'Tom Brown']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_e742a th {
#   font-size: 120%;
# }
# #T_e742a  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_e742a" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e742a_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_e742a_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e742a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e742a_row0_col0" class="data row0 col0" >Project Kickoff and Design Phase</td>
#       <td id="T_e742a_row0_col1" class="data row0 col1" >['Initial Project Kickoff', 'Create Responsive Design', 'Develop User Interface', 'User-Friendly Navigation System', 'Create "About Us" Page', 'Design "Services" Page']</td>
#     </tr>
#     <tr>
#       <th id="T_e742a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e742a_row1_col0" class="data row1 col0" >Content Creation and Implementation</td>
#       <td id="T_e742a_row1_col1" class="data row1 col1" >['Create "Contact Us" Page', 'Blog Section Implementation', 'Testimonials Section Design']</td>
#     </tr>
#     <tr>
#       <th id="T_e742a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e742a_row2_col0" class="data row2 col0" >Testing and Launch</td>
#       <td id="T_e742a_row2_col1" class="data row2 col1" >['Quality Assurance Testing', 'SEO and Performance Optimization', 'Integration of Social Media Links', 'Final Review and Project Launch']</td>
#     </tr>
#   </tbody>
# </table>
