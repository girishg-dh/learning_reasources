# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 211 packages in 1.93s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# cffi       ------------------------------     0 B/456.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# pydantic   ------------------------------     0 B/434.36 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# pydantic   ------------------------------     0 B/434.36 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# rpds-py    ------------------------------     0 B/374.67 KiB
# pydantic   ------------------------------     0 B/434.36 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# rpds-py    ------------------------------     0 B/374.67 KiB
# pydantic   ------------------------------     0 B/434.36 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------ 14.88 KiB/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# rpds-py    ------------------------------     0 B/374.67 KiB
# pydantic   ------------------------------     0 B/434.36 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------ 14.84 KiB/523.63 KiB
# pyyaml     ------------------------------ 14.88 KiB/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# rpds-py    ------------------------------     0 B/374.67 KiB
# pydantic   ------------------------------     0 B/434.36 KiB
# cffi       ------------------------------ 14.88 KiB/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------ 14.84 KiB/523.63 KiB
# pyyaml     ------------------------------ 14.88 KiB/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# rpds-py    ------------------------------     0 B/374.67 KiB
# pydantic   ------------------------------ 14.88 KiB/434.36 KiB
# cffi       ------------------------------ 14.88 KiB/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------ 14.84 KiB/523.63 KiB
# pyyaml     ------------------------------ 14.88 KiB/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# rpds-py    ------------------------------     0 B/374.67 KiB
# pydantic   ------------------------------ 14.88 KiB/434.36 KiB
# cffi       ------------------------------ 14.88 KiB/456.29 KiB
# pytz       ------------------------------ 14.88 KiB/497.29 KiB
# mpmath     ------------------------------ 14.84 KiB/523.63 KiB
# pyyaml     ------------------------------ 14.88 KiB/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# rpds-py    ------------------------------ 14.91 KiB/374.67 KiB
# pydantic   ------------------------------ 14.88 KiB/434.36 KiB
# cffi       ------------------------------ 14.88 KiB/456.29 KiB
# pytz       ------------------------------ 14.88 KiB/497.29 KiB
# mpmath     ------------------------------ 14.84 KiB/523.63 KiB
# pyyaml     ------------------------------ 14.88 KiB/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# rpds-py    ------------------------------ 14.91 KiB/374.67 KiB
# pydantic   ------------------------------ 14.88 KiB/434.36 KiB
# cffi       ------------------------------ 14.88 KiB/456.29 KiB
# pytz       ------------------------------ 14.88 KiB/497.29 KiB
# mpmath     ------------------------------ 14.84 KiB/523.63 KiB
# pyyaml     ------------------------------ 14.88 KiB/745.07 KiB
# networkx   ------------------------------ 14.88 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# rpds-py    ------------------------------ 14.91 KiB/374.67 KiB
# pydantic   ------------------------------ 14.88 KiB/434.36 KiB
# cffi       ------------------------------ 14.88 KiB/456.29 KiB
# pytz       ------------------------------ 14.88 KiB/497.29 KiB
# mpmath     ------------------------------ 14.84 KiB/523.63 KiB
# pyyaml     ------------------------------ 14.88 KiB/745.07 KiB
# networkx   ------------------------------ 14.88 KiB/1.64 MiB
# sympy      ------------------------------     0 B/6.01 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 30.89 KiB/371.70 KiB
# rpds-py    ------------------------------ 46.91 KiB/374.67 KiB
# prompt-toolkit ------------------------------ 32.00 KiB/378.72 KiB
# langchain-core ------------------------------ 15.89 KiB/433.06 KiB
# pydantic   ------------------------------ 46.88 KiB/434.36 KiB
# watchfiles ------------------------------ 16.00 KiB/442.52 KiB
# httptools  ------------------------------ 16.00 KiB/449.01 KiB
# cffi       ------------------------------ 46.88 KiB/456.29 KiB
# pytz       ------------------------------ 46.88 KiB/497.29 KiB
# mpmath     ------------------------------ 46.74 KiB/523.63 KiB
# huggingface-hub ------------------------------ 32.00 KiB/548.29 KiB
# greenlet   ------------------------------ 38.18 KiB/573.91 KiB
# chromadb   ------------------------------ 32.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 30.91 KiB/661.17 KiB
# pyvis      ------------------------------ 16.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 46.88 KiB/745.07 KiB
# openai     ------------------------------ 30.89 KiB/768.38 KiB
# regex      ------------------------------ 32.00 KiB/780.14 KiB
# ipython    ------------------------------ 16.00 KiB/812.37 KiB
# langchain  ------------------------------ 32.00 KiB/994.33 KiB
# tiktoken   ------------------------------ 30.91 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 46.89 KiB/371.70 KiB
# rpds-py    ------------------------------ 171.38 KiB/374.67 KiB
# prompt-toolkit ------------------------------ 32.00 KiB/378.72 KiB
# langchain-core ------------------------------ 15.89 KiB/433.06 KiB
# pydantic   ------------------------------ 62.88 KiB/434.36 KiB
# watchfiles ------------------------------ 16.00 KiB/442.52 KiB
# httptools  ------------------------------ 16.00 KiB/449.01 KiB
# cffi       ------------------------------ 172.99 KiB/456.29 KiB
# pytz       ------------------------------ 46.88 KiB/497.29 KiB
# mpmath     ------------------------------ 139.74 KiB/523.63 KiB
# huggingface-hub ------------------------------ 48.00 KiB/548.29 KiB
# greenlet   ------------------------------ 54.18 KiB/573.91 KiB
# chromadb   ------------------------------ 48.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 30.91 KiB/661.17 KiB
# pyvis      ------------------------------ 16.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 62.88 KiB/745.07 KiB
# openai     ------------------------------ 46.89 KiB/768.38 KiB
# regex      ------------------------------ 146.51 KiB/780.14 KiB
# ipython    ------------------------------ 16.00 KiB/812.37 KiB
# langchain  ------------------------------ 32.00 KiB/994.33 KiB
# tiktoken   ------------------------------ 174.91 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 46.89 KiB/371.70 KiB
# rpds-py    ------------------------------ 171.38 KiB/374.67 KiB
# prompt-toolkit ------------------------------ 32.00 KiB/378.72 KiB
# langchain-core ------------------------------ 15.89 KiB/433.06 KiB
# pydantic   ------------------------------ 62.88 KiB/434.36 KiB
# watchfiles ------------------------------ 16.00 KiB/442.52 KiB
# httptools  ------------------------------ 16.00 KiB/449.01 KiB
# cffi       ------------------------------ 172.99 KiB/456.29 KiB
# pytz       ------------------------------ 46.88 KiB/497.29 KiB
# mpmath     ------------------------------ 139.74 KiB/523.63 KiB
# huggingface-hub ------------------------------ 48.00 KiB/548.29 KiB
# greenlet   ------------------------------ 54.18 KiB/573.91 KiB
# chromadb   ------------------------------ 48.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 30.91 KiB/661.17 KiB
# pyvis      ------------------------------ 16.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 78.37 KiB/745.07 KiB
# openai     ------------------------------ 46.89 KiB/768.38 KiB
# regex      ------------------------------ 146.51 KiB/780.14 KiB
# ipython    ------------------------------ 16.00 KiB/812.37 KiB
# langchain  ------------------------------ 32.00 KiB/994.33 KiB
# tiktoken   ------------------------------ 174.91 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 62.89 KiB/371.70 KiB
# rpds-py    ------------------------------ 187.38 KiB/374.67 KiB
# prompt-toolkit ------------------------------ 48.00 KiB/378.72 KiB
# langchain-core ------------------------------ 31.89 KiB/433.06 KiB
# pydantic   ------------------------------ 62.88 KiB/434.36 KiB
# watchfiles ------------------------------ 158.28 KiB/442.52 KiB
# httptools  ------------------------------ 16.00 KiB/449.01 KiB
# cffi       ------------------------------ 188.99 KiB/456.29 KiB
# pytz       ------------------------------ 46.88 KiB/497.29 KiB
# mpmath     ------------------------------ 139.74 KiB/523.63 KiB
# huggingface-hub ------------------------------ 63.21 KiB/548.29 KiB
# greenlet   ------------------------------ 70.18 KiB/573.91 KiB
# chromadb   ------------------------------ 48.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 30.91 KiB/661.17 KiB
# pyvis      ------------------------------ 16.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 189.30 KiB/745.07 KiB
# openai     ------------------------------ 46.89 KiB/768.38 KiB
# regex      ------------------------------ 162.51 KiB/780.14 KiB
# ipython    ------------------------------ 32.00 KiB/812.37 KiB
# langchain  ------------------------------ 32.00 KiB/994.33 KiB
# tiktoken   ------------------------------ 190.91 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# crewai     ------------------------------ 78.89 KiB/371.70 KiB
# rpds-py    ------------------------------ 267.38 KiB/374.67 KiB
# prompt-toolkit ------------------------------ 92.92 KiB/378.72 KiB
# langchain-core ------------------------------ 47.89 KiB/433.06 KiB
# pydantic   ------------------------------ 157.16 KiB/434.36 KiB
# watchfiles ------------------------------ 222.28 KiB/442.52 KiB
# httptools  ------------------------------ 238.63 KiB/449.01 KiB
# cffi       ------------------------------ 268.99 KiB/456.29 KiB
# pytz       ------------------------------ 46.88 KiB/497.29 KiB
# mpmath     ------------------------------ 235.74 KiB/523.63 KiB
# huggingface-hub ------------------------------ 207.21 KiB/548.29 KiB
# greenlet   ------------------------------ 248.47 KiB/573.91 KiB
# chromadb   ------------------------------ 80.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 46.91 KiB/661.17 KiB
# pyvis      ------------------------------ 240.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 235.06 KiB/745.07 KiB
# openai     ------------------------------ 62.89 KiB/768.38 KiB
# regex      ------------------------------ 237.34 KiB/780.14 KiB
# ipython    ------------------------------ 109.82 KiB/812.37 KiB
# langchain  ------------------------------ 32.00 KiB/994.33 KiB
# tiktoken   ------------------------------ 270.07 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# crewai     ------------------------------ 94.89 KiB/371.70 KiB
# rpds-py    ------------------------------ 351.38 KiB/374.67 KiB
# prompt-toolkit ------------------------------ 108.92 KiB/378.72 KiB
# langchain-core ------------------------------ 76.94 KiB/433.06 KiB
# pydantic   ------------------------------ 237.16 KiB/434.36 KiB
# watchfiles ------------------------------ 302.28 KiB/442.52 KiB
# httptools  ------------------------------ 334.63 KiB/449.01 KiB
# cffi       ------------------------------ 364.99 KiB/456.29 KiB
# pytz       ------------------------------ 107.28 KiB/497.29 KiB
# mpmath     ------------------------------ 346.54 KiB/523.63 KiB
# huggingface-hub ------------------------------ 271.21 KiB/548.29 KiB
# greenlet   ------------------------------ 312.93 KiB/573.91 KiB
# chromadb   ------------------------------ 111.89 KiB/613.62 KiB
# crewai-tools ------------------------------ 78.91 KiB/661.17 KiB
# pyvis      ------------------------------ 319.89 KiB/738.32 KiB
# pyyaml     ------------------------------ 318.40 KiB/745.07 KiB
# openai     ------------------------------ 77.92 KiB/768.38 KiB
# regex      ------------------------------ 333.34 KiB/780.14 KiB
# ipython    ------------------------------ 237.82 KiB/812.37 KiB
# langchain  ------------------------------ 48.00 KiB/994.33 KiB
# tiktoken   ------------------------------ 363.95 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# crewai     ------------------------------ 110.89 KiB/371.70 KiB
# prompt-toolkit ------------------------------ 124.92 KiB/378.72 KiB
# langchain-core ------------------------------ 140.94 KiB/433.06 KiB
# pydantic   ------------------------------ 285.16 KiB/434.36 KiB
# watchfiles ------------------------------ 366.28 KiB/442.52 KiB
# httptools  ------------------------------ 393.23 KiB/449.01 KiB
# cffi       ------------------------------ 412.99 KiB/456.29 KiB
# pytz       ------------------------------ 123.28 KiB/497.29 KiB
# mpmath     ------------------------------ 394.54 KiB/523.63 KiB
# huggingface-hub ------------------------------ 367.21 KiB/548.29 KiB
# greenlet   ------------------------------ 367.71 KiB/573.91 KiB
# chromadb   ------------------------------ 368.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 94.91 KiB/661.17 KiB
# pyvis      ------------------------------ 368.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 382.37 KiB/745.07 KiB
# openai     ------------------------------ 109.92 KiB/768.38 KiB
# regex      ------------------------------ 397.34 KiB/780.14 KiB
# ipython    ------------------------------ 329.80 KiB/812.37 KiB
# langchain  ------------------------------ 48.00 KiB/994.33 KiB
# tiktoken   ------------------------------ 413.96 KiB/1.13 MiB
# pygments   ------------------------------ 364.46 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# crewai     ------------------------------ 110.89 KiB/371.70 KiB
# prompt-toolkit ------------------------------ 140.92 KiB/378.72 KiB
# langchain-core ------------------------------ 140.94 KiB/433.06 KiB
# pydantic   ------------------------------ 301.16 KiB/434.36 KiB
# watchfiles ------------------------------ 382.28 KiB/442.52 KiB
# httptools  ------------------------------ 398.63 KiB/449.01 KiB
# cffi       ------------------------------ 412.99 KiB/456.29 KiB
# pytz       ------------------------------ 123.28 KiB/497.29 KiB
# mpmath     ------------------------------ 399.74 KiB/523.63 KiB
# huggingface-hub ------------------------------ 367.21 KiB/548.29 KiB
# greenlet   ------------------------------ 387.47 KiB/573.91 KiB
# chromadb   ------------------------------ 368.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 94.91 KiB/661.17 KiB
# pyvis      ------------------------------ 384.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 398.37 KiB/745.07 KiB
# openai     ------------------------------ 109.92 KiB/768.38 KiB
# regex      ------------------------------ 429.34 KiB/780.14 KiB
# ipython    ------------------------------ 351.82 KiB/812.37 KiB
# langchain  ------------------------------ 48.00 KiB/994.33 KiB
# tiktoken   ------------------------------ 445.96 KiB/1.13 MiB
# pygments   ------------------------------ 380.46 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# langsmith  ------------------------------ 16.00 KiB/354.49 KiB
# crewai     ------------------------------ 126.78 KiB/371.70 KiB
# prompt-toolkit ------------------------------ 156.92 KiB/378.72 KiB
# langchain-core ------------------------------ 172.94 KiB/433.06 KiB
# pydantic   ------------------------------ 333.16 KiB/434.36 KiB
# httptools  ------------------------------ 449.01 KiB/449.01 KiB
# cffi       ------------------------------ 456.29 KiB/456.29 KiB
# pytz       ------------------------------ 123.28 KiB/497.29 KiB
# mpmath     ------------------------------ 431.74 KiB/523.63 KiB
# huggingface-hub ------------------------------ 383.21 KiB/548.29 KiB
# greenlet   ------------------------------ 435.24 KiB/573.91 KiB
# chromadb   ------------------------------ 368.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 110.91 KiB/661.17 KiB
# pyvis      ------------------------------ 448.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 462.37 KiB/745.07 KiB
# openai     ------------------------------ 125.92 KiB/768.38 KiB
# regex      ------------------------------ 493.34 KiB/780.14 KiB
# ipython    ------------------------------ 367.82 KiB/812.37 KiB
# langchain  ------------------------------ 61.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 494.07 KiB/1.13 MiB
# pygments   ------------------------------ 412.46 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# langsmith  ------------------------------ 16.00 KiB/354.49 KiB
# crewai     ------------------------------ 126.78 KiB/371.70 KiB
# prompt-toolkit ------------------------------ 156.92 KiB/378.72 KiB
# langchain-core ------------------------------ 172.94 KiB/433.06 KiB
# pydantic   ------------------------------ 333.16 KiB/434.36 KiB
# cffi       ------------------------------ 456.29 KiB/456.29 KiB
# pytz       ------------------------------ 123.28 KiB/497.29 KiB
# mpmath     ------------------------------ 447.74 KiB/523.63 KiB
# huggingface-hub ------------------------------ 383.21 KiB/548.29 KiB
# greenlet   ------------------------------ 451.24 KiB/573.91 KiB
# chromadb   ------------------------------ 368.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 110.91 KiB/661.17 KiB
# pyvis      ------------------------------ 448.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 478.37 KiB/745.07 KiB
# openai     ------------------------------ 125.92 KiB/768.38 KiB
# regex      ------------------------------ 493.34 KiB/780.14 KiB
# ipython    ------------------------------ 367.82 KiB/812.37 KiB
# langchain  ------------------------------ 61.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 494.07 KiB/1.13 MiB
# pygments   ------------------------------ 428.46 KiB/1.17 MiB
# jedi       ------------------------------ 237.21 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# langsmith  ------------------------------ 32.00 KiB/354.49 KiB
# crewai     ------------------------------ 126.78 KiB/371.70 KiB
# prompt-toolkit ------------------------------ 172.92 KiB/378.72 KiB
# langchain-core ------------------------------ 172.94 KiB/433.06 KiB
# pydantic   ------------------------------ 349.16 KiB/434.36 KiB
# pytz       ------------------------------ 123.28 KiB/497.29 KiB
# mpmath     ------------------------------ 447.74 KiB/523.63 KiB
# huggingface-hub ------------------------------ 399.21 KiB/548.29 KiB
# greenlet   ------------------------------ 451.24 KiB/573.91 KiB
# chromadb   ------------------------------ 368.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 110.91 KiB/661.17 KiB
# pyvis      ------------------------------ 464.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 478.37 KiB/745.07 KiB
# openai     ------------------------------ 125.92 KiB/768.38 KiB
# regex      ------------------------------ 509.34 KiB/780.14 KiB
# ipython    ------------------------------ 367.82 KiB/812.37 KiB
# langchain  ------------------------------ 61.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 510.07 KiB/1.13 MiB
# pygments   ------------------------------ 428.46 KiB/1.17 MiB
# jedi       ------------------------------ 237.21 KiB/1.50 MiB
# networkx   ------------------------------ 286.67 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# tzdata     ------------------------------     0 B/339.69 KiB
# yarl       ------------------------------ 16.00 KiB/340.80 KiB
# jiter      ------------------------------ 16.00 KiB/343.92 KiB
# langsmith  ------------------------------ 48.00 KiB/354.49 KiB
# crewai     ------------------------------ 126.78 KiB/371.70 KiB
# prompt-toolkit ------------------------------ 188.92 KiB/378.72 KiB
# langchain-core ------------------------------ 188.94 KiB/433.06 KiB
# pydantic   ------------------------------ 397.16 KiB/434.36 KiB
# pytz       ------------------------------ 123.28 KiB/497.29 KiB
# mpmath     ------------------------------ 511.74 KiB/523.63 KiB
# huggingface-hub ------------------------------ 399.21 KiB/548.29 KiB
# greenlet   ------------------------------ 463.71 KiB/573.91 KiB
# chromadb   ------------------------------ 400.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 126.91 KiB/661.17 KiB
# pyvis      ------------------------------ 496.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 510.37 KiB/745.07 KiB
# openai     ------------------------------ 157.92 KiB/768.38 KiB
# regex      ------------------------------ 540.68 KiB/780.14 KiB
# ipython    ------------------------------ 383.82 KiB/812.37 KiB
# langchain  ------------------------------ 61.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 542.07 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# yarl       ------------------------------ 48.00 KiB/340.80 KiB
# jiter      ------------------------------ 48.00 KiB/343.92 KiB
# langsmith  ------------------------------ 111.67 KiB/354.49 KiB
# crewai     ------------------------------ 126.78 KiB/371.70 KiB
# prompt-toolkit ------------------------------ 204.92 KiB/378.72 KiB
# langchain-core ------------------------------ 204.94 KiB/433.06 KiB
# pytz       ------------------------------ 123.28 KiB/497.29 KiB
# mpmath     ------------------------------ 511.74 KiB/523.63 KiB
# huggingface-hub ------------------------------ 415.21 KiB/548.29 KiB
# greenlet   ------------------------------ 463.71 KiB/573.91 KiB
# chromadb   ------------------------------ 400.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 126.91 KiB/661.17 KiB
# pyvis      ------------------------------ 527.89 KiB/738.32 KiB
# pyyaml     ------------------------------ 529.65 KiB/745.07 KiB
# openai     ------------------------------ 173.92 KiB/768.38 KiB
# regex      ------------------------------ 557.34 KiB/780.14 KiB
# ipython    ------------------------------ 413.82 KiB/812.37 KiB
# langchain  ------------------------------ 77.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 574.07 KiB/1.13 MiB
# pygments   ------------------------------ 492.46 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# yarl       ------------------------------ 62.93 KiB/340.80 KiB
# jiter      ------------------------------ 61.09 KiB/343.92 KiB
# langsmith  ------------------------------ 127.67 KiB/354.49 KiB
# crewai     ------------------------------ 126.78 KiB/371.70 KiB
# prompt-toolkit ------------------------------ 252.92 KiB/378.72 KiB
# langchain-core ------------------------------ 220.94 KiB/433.06 KiB
# pytz       ------------------------------ 123.28 KiB/497.29 KiB
# huggingface-hub ------------------------------ 415.21 KiB/548.29 KiB
# greenlet   ------------------------------ 479.71 KiB/573.91 KiB
# chromadb   ------------------------------ 400.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 158.91 KiB/661.17 KiB
# pyvis      ------------------------------ 543.89 KiB/738.32 KiB
# pyyaml     ------------------------------ 558.37 KiB/745.07 KiB
# openai     ------------------------------ 189.70 KiB/768.38 KiB
# regex      ------------------------------ 573.34 KiB/780.14 KiB
# ipython    ------------------------------ 440.04 KiB/812.37 KiB
# langchain  ------------------------------ 77.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 590.07 KiB/1.13 MiB
# pygments   ------------------------------ 512.00 KiB/1.17 MiB
# jedi       ------------------------------ 253.21 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# protobuf   ------------------------------ 15.78 KiB/314.46 KiB
# qdrant-client ------------------------------ 30.91 KiB/329.42 KiB
# tzdata     ------------------------------ 14.88 KiB/339.69 KiB
# yarl       ------------------------------ 94.93 KiB/340.80 KiB
# jiter      ------------------------------ 109.09 KiB/343.92 KiB
# langsmith  ------------------------------ 144.00 KiB/354.49 KiB
# crewai     ------------------------------ 142.89 KiB/371.70 KiB
# prompt-toolkit ------------------------------ 284.92 KiB/378.72 KiB
# langchain-core ------------------------------ 300.94 KiB/433.06 KiB
# pytz       ------------------------------ 139.28 KiB/497.29 KiB
# huggingface-hub ------------------------------ 431.21 KiB/548.29 KiB
# greenlet   ------------------------------ 511.71 KiB/573.91 KiB
# chromadb   ------------------------------ 432.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 328.20 KiB/661.17 KiB
# pyvis      ------------------------------ 571.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 590.37 KiB/745.07 KiB
# openai     ------------------------------ 237.81 KiB/768.38 KiB
# regex      ------------------------------ 621.34 KiB/780.14 KiB
# ipython    ------------------------------ 461.82 KiB/812.37 KiB
# langchain  ------------------------------ 93.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 638.07 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# protobuf   ------------------------------ 126.21 KiB/314.46 KiB
# qdrant-client ------------------------------ 110.91 KiB/329.42 KiB
# tzdata     ------------------------------ 75.47 KiB/339.69 KiB
# yarl       ------------------------------ 190.93 KiB/340.80 KiB
# jiter      ------------------------------ 221.09 KiB/343.92 KiB
# langsmith  ------------------------------ 256.00 KiB/354.49 KiB
# crewai     ------------------------------ 190.89 KiB/371.70 KiB
# prompt-toolkit ------------------------------ 364.92 KiB/378.72 KiB
# langchain-core ------------------------------ 364.94 KiB/433.06 KiB
# pytz       ------------------------------ 155.28 KiB/497.29 KiB
# huggingface-hub ------------------------------ 495.21 KiB/548.29 KiB
# greenlet   ------------------------------ 559.71 KiB/573.91 KiB
# chromadb   ------------------------------ 464.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 552.09 KiB/661.17 KiB
# pyvis      ------------------------------ 683.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 686.37 KiB/745.07 KiB
# openai     ------------------------------ 269.92 KiB/768.38 KiB
# regex      ------------------------------ 726.96 KiB/780.14 KiB
# ipython    ------------------------------ 573.82 KiB/812.37 KiB
# langchain  ------------------------------ 125.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 734.07 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# protobuf   ------------------------------ 142.21 KiB/314.46 KiB
# qdrant-client ------------------------------ 126.91 KiB/329.42 KiB
# tzdata     ------------------------------ 75.47 KiB/339.69 KiB
# yarl       ------------------------------ 215.55 KiB/340.80 KiB
# jiter      ------------------------------ 237.09 KiB/343.92 KiB
# langsmith  ------------------------------ 272.00 KiB/354.49 KiB
# crewai     ------------------------------ 206.89 KiB/371.70 KiB
# prompt-toolkit ------------------------------ 364.92 KiB/378.72 KiB
# langchain-core ------------------------------ 380.83 KiB/433.06 KiB
# pytz       ------------------------------ 155.28 KiB/497.29 KiB
# huggingface-hub ------------------------------ 511.21 KiB/548.29 KiB
# chromadb   ------------------------------ 480.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 568.09 KiB/661.17 KiB
# pyvis      ------------------------------ 715.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 702.37 KiB/745.07 KiB
# openai     ------------------------------ 285.92 KiB/768.38 KiB
# regex      ------------------------------ 733.34 KiB/780.14 KiB
# ipython    ------------------------------ 573.82 KiB/812.37 KiB
# langchain  ------------------------------ 125.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 765.96 KiB/1.13 MiB
# pygments   ------------------------------ 684.46 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# protobuf   ------------------------------ 158.21 KiB/314.46 KiB
# qdrant-client ------------------------------ 142.91 KiB/329.42 KiB
# tzdata     ------------------------------ 75.47 KiB/339.69 KiB
# yarl       ------------------------------ 231.55 KiB/340.80 KiB
# jiter      ------------------------------ 253.09 KiB/343.92 KiB
# langsmith  ------------------------------ 288.00 KiB/354.49 KiB
# crewai     ------------------------------ 206.89 KiB/371.70 KiB
# langchain-core ------------------------------ 380.83 KiB/433.06 KiB
# pytz       ------------------------------ 155.28 KiB/497.29 KiB
# huggingface-hub ------------------------------ 526.42 KiB/548.29 KiB
# chromadb   ------------------------------ 480.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 568.09 KiB/661.17 KiB
# pyvis      ------------------------------ 731.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 717.08 KiB/745.07 KiB
# openai     ------------------------------ 289.71 KiB/768.38 KiB
# regex      ------------------------------ 749.34 KiB/780.14 KiB
# ipython    ------------------------------ 589.82 KiB/812.37 KiB
# langchain  ------------------------------ 125.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 781.96 KiB/1.13 MiB
# pygments   ------------------------------ 684.46 KiB/1.17 MiB
# jedi       ------------------------------ 269.21 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# anthropic  ------------------------------     0 B/290.28 KiB
# pypdf      ------------------------------ 14.92 KiB/305.85 KiB
# protobuf   ------------------------------ 190.21 KiB/314.46 KiB
# qdrant-client ------------------------------ 153.01 KiB/329.42 KiB
# tzdata     ------------------------------ 91.47 KiB/339.69 KiB
# yarl       ------------------------------ 253.29 KiB/340.80 KiB
# jiter      ------------------------------ 285.09 KiB/343.92 KiB
# langsmith  ------------------------------ 320.00 KiB/354.49 KiB
# crewai     ------------------------------ 206.89 KiB/371.70 KiB
# langchain-core ------------------------------ 396.83 KiB/433.06 KiB
# pytz       ------------------------------ 171.28 KiB/497.29 KiB
# chromadb   ------------------------------ 480.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 568.09 KiB/661.17 KiB
# pyvis      ------------------------------ 738.32 KiB/738.32 KiB
# pyyaml     ------------------------------ 734.05 KiB/745.07 KiB
# openai     ------------------------------ 305.71 KiB/768.38 KiB
# regex      ------------------------------ 780.14 KiB/780.14 KiB
# ipython    ------------------------------ 629.05 KiB/812.37 KiB
# langchain  ------------------------------ 141.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 798.07 KiB/1.13 MiB
# pygments   ------------------------------ 764.46 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# anthropic  ------------------------------     0 B/290.28 KiB
# pypdf      ------------------------------ 30.49 KiB/305.85 KiB
# protobuf   ------------------------------ 190.21 KiB/314.46 KiB
# qdrant-client ------------------------------ 153.01 KiB/329.42 KiB
# tzdata     ------------------------------ 91.47 KiB/339.69 KiB
# yarl       ------------------------------ 253.29 KiB/340.80 KiB
# jiter      ------------------------------ 285.09 KiB/343.92 KiB
# langsmith  ------------------------------ 320.00 KiB/354.49 KiB
# crewai     ------------------------------ 206.89 KiB/371.70 KiB
# langchain-core ------------------------------ 412.94 KiB/433.06 KiB
# pytz       ------------------------------ 171.28 KiB/497.29 KiB
# chromadb   ------------------------------ 480.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 568.09 KiB/661.17 KiB
# pyyaml     ------------------------------ 734.37 KiB/745.07 KiB
# openai     ------------------------------ 305.71 KiB/768.38 KiB
# regex      ------------------------------ 780.14 KiB/780.14 KiB
# ipython    ------------------------------ 629.05 KiB/812.37 KiB
# langchain  ------------------------------ 141.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 798.07 KiB/1.13 MiB
# pygments   ------------------------------ 780.46 KiB/1.17 MiB
# jedi       ------------------------------ 269.21 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# anthropic  ------------------------------     0 B/290.28 KiB
# pypdf      ------------------------------ 30.49 KiB/305.85 KiB
# protobuf   ------------------------------ 205.75 KiB/314.46 KiB
# qdrant-client ------------------------------ 169.01 KiB/329.42 KiB
# tzdata     ------------------------------ 91.47 KiB/339.69 KiB
# yarl       ------------------------------ 253.29 KiB/340.80 KiB
# jiter      ------------------------------ 285.09 KiB/343.92 KiB
# langsmith  ------------------------------ 320.00 KiB/354.49 KiB
# crewai     ------------------------------ 206.89 KiB/371.70 KiB
# langchain-core ------------------------------ 412.94 KiB/433.06 KiB
# pytz       ------------------------------ 171.28 KiB/497.29 KiB
# chromadb   ------------------------------ 496.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 568.09 KiB/661.17 KiB
# pyyaml     ------------------------------ 734.37 KiB/745.07 KiB
# openai     ------------------------------ 305.71 KiB/768.38 KiB
# ipython    ------------------------------ 629.05 KiB/812.37 KiB
# langchain  ------------------------------ 141.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 798.07 KiB/1.13 MiB
# pygments   ------------------------------ 780.46 KiB/1.17 MiB
# jedi       ------------------------------ 269.21 KiB/1.50 MiB
# networkx   ------------------------------ 446.67 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# bcrypt     ------------------------------     0 B/277.50 KiB
# googleapis-common-protos ------------------------------     0 B/287.63 KiB
# cohere     ------------------------------ 4.08 KiB/288.38 KiB
# anthropic  ------------------------------ 19.09 KiB/290.28 KiB
# pypdf      ------------------------------ 46.49 KiB/305.85 KiB
# protobuf   ------------------------------ 221.75 KiB/314.46 KiB
# qdrant-client ------------------------------ 169.01 KiB/329.42 KiB
# tzdata     ------------------------------ 91.47 KiB/339.69 KiB
# yarl       ------------------------------ 270.93 KiB/340.80 KiB
# jiter      ------------------------------ 317.09 KiB/343.92 KiB
# langsmith  ------------------------------ 352.00 KiB/354.49 KiB
# crewai     ------------------------------ 206.89 KiB/371.70 KiB
# pytz       ------------------------------ 171.28 KiB/497.29 KiB
# chromadb   ------------------------------ 496.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 584.09 KiB/661.17 KiB
# pyyaml     ------------------------------ 745.07 KiB/745.07 KiB
# openai     ------------------------------ 305.71 KiB/768.38 KiB
# ipython    ------------------------------ 629.05 KiB/812.37 KiB
# langchain  ------------------------------ 141.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 830.07 KiB/1.13 MiB
# pygments   ------------------------------ 796.46 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# bcrypt     ------------------------------     0 B/277.50 KiB
# googleapis-common-protos ------------------------------     0 B/287.63 KiB
# cohere     ------------------------------ 4.08 KiB/288.38 KiB
# anthropic  ------------------------------ 19.09 KiB/290.28 KiB
# pypdf      ------------------------------ 46.49 KiB/305.85 KiB
# protobuf   ------------------------------ 221.75 KiB/314.46 KiB
# qdrant-client ------------------------------ 169.01 KiB/329.42 KiB
# tzdata     ------------------------------ 91.47 KiB/339.69 KiB
# yarl       ------------------------------ 270.93 KiB/340.80 KiB
# jiter      ------------------------------ 317.09 KiB/343.92 KiB
# langsmith  ------------------------------ 352.00 KiB/354.49 KiB
# crewai     ------------------------------ 206.89 KiB/371.70 KiB
# pytz       ------------------------------ 171.28 KiB/497.29 KiB
# chromadb   ------------------------------ 496.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 584.09 KiB/661.17 KiB
# openai     ------------------------------ 305.71 KiB/768.38 KiB
# ipython    ------------------------------ 629.05 KiB/812.37 KiB
# langchain  ------------------------------ 141.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 830.07 KiB/1.13 MiB
# pygments   ------------------------------ 796.46 KiB/1.17 MiB
# jedi       ------------------------------ 269.21 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# bcrypt     ------------------------------     0 B/277.50 KiB
# googleapis-common-protos ------------------------------     0 B/287.63 KiB
# cohere     ------------------------------ 4.08 KiB/288.38 KiB
# anthropic  ------------------------------ 19.09 KiB/290.28 KiB
# pypdf      ------------------------------ 46.49 KiB/305.85 KiB
# protobuf   ------------------------------ 221.75 KiB/314.46 KiB
# qdrant-client ------------------------------ 185.01 KiB/329.42 KiB
# tzdata     ------------------------------ 91.47 KiB/339.69 KiB
# yarl       ------------------------------ 270.93 KiB/340.80 KiB
# jiter      ------------------------------ 317.09 KiB/343.92 KiB
# langsmith  ------------------------------ 352.00 KiB/354.49 KiB
# crewai     ------------------------------ 206.89 KiB/371.70 KiB
# pytz       ------------------------------ 171.28 KiB/497.29 KiB
# chromadb   ------------------------------ 496.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 584.09 KiB/661.17 KiB
# openai     ------------------------------ 305.71 KiB/768.38 KiB
# ipython    ------------------------------ 629.05 KiB/812.37 KiB
# langchain  ------------------------------ 141.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 830.07 KiB/1.13 MiB
# pygments   ------------------------------ 796.46 KiB/1.17 MiB
# jedi       ------------------------------ 269.21 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# bcrypt     ------------------------------ 14.88 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 14.87 KiB/287.63 KiB
# cohere     ------------------------------ 4.08 KiB/288.38 KiB
# anthropic  ------------------------------ 35.09 KiB/290.28 KiB
# pypdf      ------------------------------ 62.49 KiB/305.85 KiB
# protobuf   ------------------------------ 237.75 KiB/314.46 KiB
# qdrant-client ------------------------------ 201.01 KiB/329.42 KiB
# tzdata     ------------------------------ 91.47 KiB/339.69 KiB
# yarl       ------------------------------ 286.93 KiB/340.80 KiB
# jiter      ------------------------------ 333.09 KiB/343.92 KiB
# crewai     ------------------------------ 222.89 KiB/371.70 KiB
# pytz       ------------------------------ 187.28 KiB/497.29 KiB
# chromadb   ------------------------------ 496.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 600.20 KiB/661.17 KiB
# openai     ------------------------------ 305.71 KiB/768.38 KiB
# ipython    ------------------------------ 645.03 KiB/812.37 KiB
# langchain  ------------------------------ 141.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 846.07 KiB/1.13 MiB
# pygments   ------------------------------ 812.46 KiB/1.17 MiB
# jedi       ------------------------------ 285.21 KiB/1.50 MiB
# networkx   ------------------------------ 478.67 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# multidict  ------------------------------     0 B/240.93 KiB
# alembic    ------------------------------ 16.00 KiB/241.24 KiB
# openpyxl   ------------------------------ 16.00 KiB/245.03 KiB
# bcrypt     ------------------------------ 30.88 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 14.87 KiB/287.63 KiB
# cohere     ------------------------------ 30.89 KiB/288.38 KiB
# anthropic  ------------------------------ 51.09 KiB/290.28 KiB
# pypdf      ------------------------------ 78.92 KiB/305.85 KiB
# protobuf   ------------------------------ 254.21 KiB/314.46 KiB
# qdrant-client ------------------------------ 222.09 KiB/329.42 KiB
# tzdata     ------------------------------ 91.47 KiB/339.69 KiB
# yarl       ------------------------------ 295.61 KiB/340.80 KiB
# crewai     ------------------------------ 222.89 KiB/371.70 KiB
# pytz       ------------------------------ 187.28 KiB/497.29 KiB
# chromadb   ------------------------------ 496.00 KiB/613.62 KiB
# crewai-tools ------------------------------ 600.20 KiB/661.17 KiB
# openai     ------------------------------ 321.71 KiB/768.38 KiB
# ipython    ------------------------------ 661.03 KiB/812.37 KiB
# langchain  ------------------------------ 141.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 862.07 KiB/1.13 MiB
# pygments   ------------------------------ 844.46 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/204)
# rich       ------------------------------ 32.00 KiB/236.74 KiB
# multidict  ------------------------------ 48.00 KiB/240.93 KiB
# alembic    ------------------------------ 62.44 KiB/241.24 KiB
# openpyxl   ------------------------------ 17.94 KiB/245.03 KiB
# bcrypt     ------------------------------ 79.81 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 46.87 KiB/287.63 KiB
# cohere     ------------------------------ 46.89 KiB/288.38 KiB
# anthropic  ------------------------------ 61.82 KiB/290.28 KiB
# pypdf      ------------------------------ 126.92 KiB/305.85 KiB
# protobuf   ------------------------------ 286.21 KiB/314.46 KiB
# qdrant-client ------------------------------ 254.09 KiB/329.42 KiB
# tzdata     ------------------------------ 91.47 KiB/339.69 KiB
# yarl       ------------------------------ 340.80 KiB/340.80 KiB
# crewai     ------------------------------ 238.89 KiB/371.70 KiB
# pytz       ------------------------------ 203.28 KiB/497.29 KiB
# chromadb   ------------------------------ 560.90 KiB/613.62 KiB
# crewai-tools ------------------------------ 632.20 KiB/661.17 KiB
# openai     ------------------------------ 321.71 KiB/768.38 KiB
# ipython    ------------------------------ 684.85 KiB/812.37 KiB
# langchain  ------------------------------ 157.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 910.07 KiB/1.13 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (15/204)
# rich       ------------------------------ 48.00 KiB/236.74 KiB
# multidict  ------------------------------ 62.29 KiB/240.93 KiB
# alembic    ------------------------------ 78.44 KiB/241.24 KiB
# openpyxl   ------------------------------ 33.94 KiB/245.03 KiB
# bcrypt     ------------------------------ 95.81 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 46.87 KiB/287.63 KiB
# cohere     ------------------------------ 48.07 KiB/288.38 KiB
# anthropic  ------------------------------ 77.82 KiB/290.28 KiB
# pypdf      ------------------------------ 142.92 KiB/305.85 KiB
# protobuf   ------------------------------ 302.21 KiB/314.46 KiB
# qdrant-client ------------------------------ 254.09 KiB/329.42 KiB
# tzdata     ------------------------------ 91.47 KiB/339.69 KiB
# crewai     ------------------------------ 238.89 KiB/371.70 KiB
# pytz       ------------------------------ 203.28 KiB/497.29 KiB
# chromadb   ------------------------------ 560.90 KiB/613.62 KiB
# crewai-tools ------------------------------ 632.20 KiB/661.17 KiB
# openai     ------------------------------ 321.71 KiB/768.38 KiB
# ipython    ------------------------------ 688.72 KiB/812.37 KiB
# langchain  ------------------------------ 157.94 KiB/994.33 KiB
# tiktoken   ------------------------------ 926.07 KiB/1.13 MiB
# pygments   ------------------------------ 908.46 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (15/204)
# tomli      ------------------------------ 16.00 KiB/230.50 KiB
# rich       ------------------------------ 61.02 KiB/236.74 KiB
# multidict  ------------------------------ 110.29 KiB/240.93 KiB
# alembic    ------------------------------ 142.44 KiB/241.24 KiB
# openpyxl   ------------------------------ 33.94 KiB/245.03 KiB
# bcrypt     ------------------------------ 143.81 KiB/277.50 KiB
# googleapis-common-protos ------------------------------ 78.52 KiB/287.63 KiB
# cohere     ------------------------------ 78.89 KiB/288.38 KiB
# anthropic  ------------------------------ 93.82 KiB/290.28 KiB
# pypdf      ------------------------------ 202.05 KiB/305.85 KiB
# protobuf   ------------------------------ 314.46 KiB/314.46 KiB
# qdrant-client ------------------------------ 318.91 KiB/329.42 KiB
# tzdata     ------------------------------ 91.47 KiB/339.69 KiB
# crewai     ------------------------------ 250.77 KiB/371.70 KiB
# pytz       ------------------------------ 203.28 KiB/497.29 KiB
# chromadb   ------------------------------ 560.90 KiB/613.62 KiB
# openai     ------------------------------ 333.92 KiB/768.38 KiB
# ...
# lancedb    ------------------------------ 20.73 MiB/33.34 MiB
# pyarrow    ------------------------------ 19.86 MiB/40.84 MiB
# ⠙ Preparing packages... (197/204) 21.30 MiB/43.79 MiB
# pyright    ------------------------------ 2.89 MiB/5.63 MiB
# pandas     ------------------------------ 10.52 MiB/11.82 MiB
# onnxruntime ------------------------------ 15.47 MiB/15.63 MiB
# uv         ------------------------------ 18.55 MiB/18.55 MiB
# lancedb    ------------------------------ 20.73 MiB/33.34 MiB
# pyarrow    ------------------------------ 19.86 MiB/40.84 MiB
# ⠙ Preparing packages... (197/204) 21.37 MiB/43.79 MiB
# pyright    ------------------------------ 2.89 MiB/5.63 MiB
# pandas     ------------------------------ 10.52 MiB/11.82 MiB
# uv         ------------------------------ 18.55 MiB/18.55 MiB
# lancedb    ------------------------------ 20.73 MiB/33.34 MiB
# pyarrow    ------------------------------ 19.86 MiB/40.84 MiB
# ⠙ Preparing packages... (197/204) 21.39 MiB/43.79 MiB
# pyright    ------------------------------ 2.90 MiB/5.63 MiB
# pandas     ------------------------------ 10.54 MiB/11.82 MiB
# uv         ------------------------------ 18.55 MiB/18.55 MiB
# lancedb    ------------------------------ 21.84 MiB/33.34 MiB
# pyarrow    ------------------------------ 20.83 MiB/40.84 MiB
# ⠙ Preparing packages... (197/204) 21.39 MiB/43.79 MiB
# pyright    ------------------------------ 3.01 MiB/5.63 MiB
# pandas     ------------------------------ 10.70 MiB/11.82 MiB
# uv         ------------------------------ 18.55 MiB/18.55 MiB
# lancedb    ------------------------------ 22.96 MiB/33.34 MiB
# pyarrow    ------------------------------ 22.20 MiB/40.84 MiB
# ⠙ Preparing packages... (197/204) 21.39 MiB/43.79 MiB
# pyright    ------------------------------ 3.14 MiB/5.63 MiB
# pandas     ------------------------------ 10.70 MiB/11.82 MiB
# uv         ------------------------------ 18.55 MiB/18.55 MiB
# lancedb    ------------------------------ 22.96 MiB/33.34 MiB
# pyarrow    ------------------------------ 22.50 MiB/40.84 MiB
# ⠹ Preparing packages... (198/204) 23.31 MiB/43.79 MiB
# pyright    ------------------------------ 3.14 MiB/5.63 MiB
# pandas     ------------------------------ 10.71 MiB/11.82 MiB
# uv         ------------------------------ 18.55 MiB/18.55 MiB
# lancedb    ------------------------------ 22.96 MiB/33.34 MiB
# pyarrow    ------------------------------ 23.09 MiB/40.84 MiB
# ⠹ Preparing packages... (198/204) 24.05 MiB/43.79 MiB
# pyright    ------------------------------ 3.14 MiB/5.63 MiB
# pandas     ------------------------------ 11.36 MiB/11.82 MiB
# uv         ------------------------------ 18.55 MiB/18.55 MiB
# lancedb    ------------------------------ 24.34 MiB/33.34 MiB
# pyarrow    ------------------------------ 23.09 MiB/40.84 MiB
# ⠹ Preparing packages... (198/204) 24.08 MiB/43.79 MiB
# pyright    ------------------------------ 3.14 MiB/5.63 MiB
# uv         ------------------------------ 18.55 MiB/18.55 MiB
# lancedb    ------------------------------ 25.26 MiB/33.34 MiB
# pyarrow    ------------------------------ 23.09 MiB/40.84 MiB
# ⠸ Preparing packages... (199/204) 24.08 MiB/43.79 MiB
# pyright    ------------------------------ 3.14 MiB/5.63 MiB
# uv         ------------------------------ 18.55 MiB/18.55 MiB
# lancedb    ------------------------------ 25.42 MiB/33.34 MiB
# pyarrow    ------------------------------ 23.09 MiB/40.84 MiB
# ⠸ Preparing packages... (199/204) 24.08 MiB/43.79 MiB
# pyright    ------------------------------ 3.15 MiB/5.63 MiB
# uv         ------------------------------ 18.55 MiB/18.55 MiB
# lancedb    ------------------------------ 25.42 MiB/33.34 MiB
# pyarrow    ------------------------------ 23.09 MiB/40.84 MiB
# ⠸ Preparing packages... (199/204) 24.08 MiB/43.79 MiB
# pyright    ------------------------------ 3.21 MiB/5.63 MiB
# uv         ------------------------------ 18.55 MiB/18.55 MiB
# lancedb    ------------------------------ 25.81 MiB/33.34 MiB
# pyarrow    ------------------------------ 23.09 MiB/40.84 MiB
# ⠸ Preparing packages... (199/204) 26.06 MiB/43.79 MiB
# pyright    ------------------------------ 3.21 MiB/5.63 MiB
# lancedb    ------------------------------ 25.81 MiB/33.34 MiB
# pyarrow    ------------------------------ 23.09 MiB/40.84 MiB
# ⠼ Preparing packages... (200/204) 26.15 MiB/43.79 MiB
# pyright    ------------------------------ 3.21 MiB/5.63 MiB
# lancedb    ------------------------------ 25.81 MiB/33.34 MiB
# pyarrow    ------------------------------ 23.09 MiB/40.84 MiB
# ⠼ Preparing packages... (200/204) 26.15 MiB/43.79 MiB
# pyright    ------------------------------ 3.23 MiB/5.63 MiB
# lancedb    ------------------------------ 25.81 MiB/33.34 MiB
# pyarrow    ------------------------------ 23.09 MiB/40.84 MiB
# ⠼ Preparing packages... (200/204) 26.15 MiB/43.79 MiB
# pyright    ------------------------------ 3.25 MiB/5.63 MiB
# lancedb    ------------------------------ 25.81 MiB/33.34 MiB
# pyarrow    ------------------------------ 23.09 MiB/40.84 MiB
# ⠼ Preparing packages... (200/204) 26.15 MiB/43.79 MiB
# pyright    ------------------------------ 3.26 MiB/5.63 MiB
# lancedb    ------------------------------ 25.81 MiB/33.34 MiB
# pyarrow    ------------------------------ 23.09 MiB/40.84 MiB
# ⠼ Preparing packages... (200/204) 26.15 MiB/43.79 MiB
# pyright    ------------------------------ 3.28 MiB/5.63 MiB
# lancedb    ------------------------------ 27.42 MiB/33.34 MiB
# pyarrow    ------------------------------ 25.80 MiB/40.84 MiB
# ⠼ Preparing packages... (200/204) 26.23 MiB/43.79 MiB
# pyright    ------------------------------ 3.28 MiB/5.63 MiB
# lancedb    ------------------------------ 28.61 MiB/33.34 MiB
# pyarrow    ------------------------------ 27.44 MiB/40.84 MiB
# ⠴ Preparing packages... (200/204) 29.07 MiB/43.79 MiB
# pyright    ------------------------------ 3.28 MiB/5.63 MiB
# lancedb    ------------------------------ 29.97 MiB/33.34 MiB
# pyarrow    ------------------------------ 29.06 MiB/40.84 MiB
# ⠴ Preparing packages... (200/204) 30.69 MiB/43.79 MiB
# pyright    ------------------------------ 3.28 MiB/5.63 MiB
# lancedb    ------------------------------ 30.05 MiB/33.34 MiB
# pyarrow    ------------------------------ 29.06 MiB/40.84 MiB
# ⠴ Preparing packages... (200/204) 30.69 MiB/43.79 MiB
# pyright    ------------------------------ 3.28 MiB/5.63 MiB
# lancedb    ------------------------------ 30.11 MiB/33.34 MiB
# pyarrow    ------------------------------ 29.06 MiB/40.84 MiB
# ⠴ Preparing packages... (200/204) 30.69 MiB/43.79 MiB
# pyright    ------------------------------ 3.28 MiB/5.63 MiB
# lancedb    ------------------------------ 31.50 MiB/33.34 MiB
# pyarrow    ------------------------------ 29.06 MiB/40.84 MiB
# ⠴ Preparing packages... (200/204) 30.83 MiB/43.79 MiB
# pyright    ------------------------------ 3.32 MiB/5.63 MiB
# lancedb    ------------------------------ 32.03 MiB/33.34 MiB
# pyarrow    ------------------------------ 29.06 MiB/40.84 MiB
# ⠦ Preparing packages... (200/204) 31.19 MiB/43.79 MiB
# pyright    ------------------------------ 3.40 MiB/5.63 MiB
# lancedb    ------------------------------ 32.04 MiB/33.34 MiB
# pyarrow    ------------------------------ 30.17 MiB/40.84 MiB
# ⠧ Preparing packages... (200/204) 32.56 MiB/43.79 MiB
# pyright    ------------------------------ 3.40 MiB/5.63 MiB
# lancedb    ------------------------------ 32.65 MiB/33.34 MiB
# pyarrow    ------------------------------ 30.17 MiB/40.84 MiB
# ⠧ Preparing packages... (200/204) 32.56 MiB/43.79 MiB
# pyright    ------------------------------ 3.40 MiB/5.63 MiB
# lancedb    ------------------------------ 32.65 MiB/33.34 MiB
# pyarrow    ------------------------------ 30.17 MiB/40.84 MiB
# ⠧ Preparing packages... (200/204) 32.67 MiB/43.79 MiB
# pyright    ------------------------------ 3.40 MiB/5.63 MiB
# lancedb    ------------------------------ 32.65 MiB/33.34 MiB
# pyarrow    ------------------------------ 30.17 MiB/40.84 MiB
# ⠧ Preparing packages... (200/204) 32.67 MiB/43.79 MiB
# pyright    ------------------------------ 3.40 MiB/5.63 MiB
# lancedb    ------------------------------ 32.65 MiB/33.34 MiB
# pyarrow    ------------------------------ 30.27 MiB/40.84 MiB
# ⠧ Preparing packages... (200/204) 32.82 MiB/43.79 MiB
# pyright    ------------------------------ 3.43 MiB/5.63 MiB
# lancedb    ------------------------------ 32.97 MiB/33.34 MiB
# pyarrow    ------------------------------ 31.31 MiB/40.84 MiB
# ⠧ Preparing packages... (200/204) 34.64 MiB/43.79 MiB
# pyright    ------------------------------ 3.57 MiB/5.63 MiB
# lancedb    ------------------------------ 33.11 MiB/33.34 MiB
# pyarrow    ------------------------------ 31.62 MiB/40.84 MiB
# ⠇ Preparing packages... (200/204) 35.04 MiB/43.79 MiB
# pyright    ------------------------------ 3.78 MiB/5.63 MiB
# lancedb    ------------------------------ 33.11 MiB/33.34 MiB
# pyarrow    ------------------------------ 31.62 MiB/40.84 MiB
# ⠇ Preparing packages... (200/204) 35.04 MiB/43.79 MiB
# pyright    ------------------------------ 4.03 MiB/5.63 MiB
# lancedb    ------------------------------ 33.11 MiB/33.34 MiB
# pyarrow    ------------------------------ 31.62 MiB/40.84 MiB
# ⠇ Preparing packages... (200/204) 35.04 MiB/43.79 MiB
# pyright    ------------------------------ 4.46 MiB/5.63 MiB
# lancedb    ------------------------------ 33.11 MiB/33.34 MiB
# pyarrow    ------------------------------ 31.62 MiB/40.84 MiB
# ⠇ Preparing packages... (200/204) 35.04 MiB/43.79 MiB
# pyright    ------------------------------ 4.51 MiB/5.63 MiB
# lancedb    ------------------------------ 33.27 MiB/33.34 MiB
# pyarrow    ------------------------------ 32.98 MiB/40.84 MiB
# ⠇ Preparing packages... (200/204) 37.59 MiB/43.79 MiB
# pyright    ------------------------------ 4.52 MiB/5.63 MiB
# pyarrow    ------------------------------ 33.72 MiB/40.84 MiB
# ⠇ Preparing packages... (200/204) 39.97 MiB/43.79 MiB
# pyright    ------------------------------ 4.52 MiB/5.63 MiB
# pyarrow    ------------------------------ 33.79 MiB/40.84 MiB
# ⠋ Preparing packages... (201/204) 41.41 MiB/43.79 MiB
# pyright    ------------------------------ 4.61 MiB/5.63 MiB
# pyarrow    ------------------------------ 36.95 MiB/40.84 MiB
# ⠋ Preparing packages... (201/204) 41.68 MiB/43.79 MiB
# pyright    ------------------------------ 4.75 MiB/5.63 MiB
# pyarrow    ------------------------------ 37.13 MiB/40.84 MiB
# ⠋ Preparing packages... (201/204) 42.83 MiB/43.79 MiB
# pyright    ------------------------------ 4.78 MiB/5.63 MiB
# ⠋ Preparing packages... (201/204) 37.19 MiB/40.84 MiB
# ⠋ Preparing packages... (201/204) 37.31 MiB/40.84 MiB
# ⠋ Preparing packages... (201/204) 37.38 MiB/40.84 MiB
# ⠙ Preparing packages... (203/204) 37.75 MiB/40.84 MiB
# ⠙ Preparing packages... (203/204) 39.24 MiB/40.84 MiB
# Prepared 204 packages in 7.32s
# Installed 204 packages in 185ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.12.15
#  + aiosignal==1.4.0
#  + alembic==1.16.4
#  + annotated-types==0.7.0
#  + anthropic==0.64.0
#  + anyio==4.10.0
#  + appdirs==1.4.4
#  + asgiref==3.9.1
#  + asttokens==3.0.0
#  + attrs==25.3.0
#  + backoff==2.2.1
#  + bcrypt==4.3.0
#  + beautifulsoup4==4.13.5
#  + blinker==1.9.0
#  + browserbase==1.4.0
#  + build==1.3.0
#  + cachetools==5.5.2
#  + certifi==2025.8.3
#  + cffi==1.17.1
#  + charset-normalizer==3.4.3
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.23
#  + click==8.2.1
#  + cohere==5.17.0
#  + coloredlogs==15.0.1
#  + crewai==0.165.1
#  + crewai-tools==0.62.3
#  + cryptography==45.0.6
#  + dataclasses-json==0.6.7
#  + decorator==5.2.1
#  + deprecation==2.1.0
#  + diskcache==5.6.3
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.17.0
#  + durationpy==0.10
#  + embedchain==0.1.128
#  + et-xmlfile==2.0.0
#  + executing==2.2.0
#  + fastapi==0.116.1
#  + fastavro==1.12.0
#  + filelock==3.19.1
#  + flatbuffers==25.2.10
#  + frozenlist==1.7.0
#  + fsspec==2025.7.0
#  + google-auth==2.40.3
#  + googleapis-common-protos==1.70.0
#  + gptcache==0.1.44
#  + greenlet==3.2.4
#  + grpcio==1.74.0
#  + h11==0.16.0
#  + h2==4.3.0
#  + hf-xet==1.1.8
#  + hpack==4.1.0
#  + httpcore==1.0.9
#  + httptools==0.6.4
#  + httpx==0.28.1
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.34.4
#  + humanfriendly==10.0
#  + hyperframe==6.1.0
#  + idna==3.10
#  + importlib-metadata==8.7.0
#  + importlib-resources==6.5.2
#  + instructor==1.10.0
#  + ipython==8.37.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.10.0
#  + json-repair==0.25.2
#  + json5==0.12.1
#  + jsonpatch==1.33
#  + jsonpickle==4.1.1
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.25.1
#  + jsonschema-specifications==2025.4.1
#  + kubernetes==33.1.0
#  + lancedb==0.24.3
#  + langchain==0.3.27
#  + langchain-cohere==0.3.5
#  + langchain-community==0.3.27
#  + langchain-core==0.3.74
#  + langchain-experimental==0.3.4
#  + langchain-openai==0.2.14
#  + langchain-text-splitters==0.3.9
#  + langsmith==0.3.45
#  + litellm==1.74.9
#  + mako==1.3.10
#  + markdown-it-py==4.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.26.1
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.115
#  + mmh3==5.2.0
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.6.4
#  + mypy-extensions==1.1.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==2.2.6
#  + oauthlib==3.3.1
#  + onnxruntime==1.22.0
#  + openai==1.99.9
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.36.0
#  + opentelemetry-exporter-otlp-proto-common==1.36.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.36.0
#  + opentelemetry-exporter-otlp-proto-http==1.36.0
#  + opentelemetry-instrumentation==0.57b0
#  + opentelemetry-instrumentation-asgi==0.57b0
#  + opentelemetry-instrumentation-fastapi==0.57b0
#  + opentelemetry-proto==1.36.0
#  + opentelemetry-sdk==1.36.0
#  + opentelemetry-semantic-conventions==0.57b0
#  + opentelemetry-util-http==0.57b0
#  + orjson==3.11.2
#  + overrides==7.7.0
#  + packaging==25.0
#  + pandas==2.3.2
#  + parso==0.8.5
#  + pdfminer-six==20250506
#  + pdfplumber==0.11.7
#  + pexpect==4.9.0
#  + pillow==11.3.0
#  + playwright==1.54.0
#  + portalocker==2.7.0
#  + posthog==3.25.0
#  + prompt-toolkit==3.0.51
#  + propcache==0.3.2
#  + protobuf==6.32.0
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==21.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pycparser==2.22
#  + pydantic==2.11.7
#  + pydantic-core==2.33.2
#  + pydantic-settings==2.10.1
#  + pyee==13.0.0
#  + pygments==2.19.2
#  + pyjwt==2.10.1
#  + pypdf==5.9.0
#  + pypdfium2==4.30.0
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.404
#  + pysbd==0.3.4
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.1.1
#  + pytube==15.0.0
#  + pytz==2025.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.15.1
#  + referencing==0.36.2
#  + regex==2025.7.34
#  + requests==2.32.5
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + rich==13.9.4
#  + rpds-py==0.27.0
#  + rsa==4.9.1
#  + schema==0.7.7
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.7
#  + sqlalchemy==2.0.43
#  + stack-data==0.6.3
#  + stagehand==0.5.0
#  + starlette==0.47.3
#  + sympy==1.14.0
#  + tabulate==0.9.0
#  + tenacity==9.1.2
#  + tiktoken==0.11.0
#  + tokenizers==0.20.3
#  + tomli==2.2.1
#  + tomli-w==1.2.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + typer==0.16.1
#  + types-requests==2.32.4.20250809
#  + typing-extensions==4.14.1
#  + typing-inspect==0.9.0
#  + typing-inspection==0.4.1
#  + tzdata==2025.2
#  + urllib3==2.5.0
#  + uv==0.8.13
#  + uvicorn==0.35.0
#  + uvloop==0.21.0
#  + watchfiles==1.1.0
#  + wcwidth==0.2.13
#  + websocket-client==1.8.0
#  + websockets==15.0.1
#  + wrapt==1.17.3
#  + yarl==1.20.1
#  + zipp==3.23.0
#  + zstandard==0.23.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 60466dc8-9d23-460e-9c97-d38638bacc75                                    │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: 8ce602c0-8e7a-4db7-a466-54deabd0f1a0
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Task: Conduct a thorough research about AI LLMs Make sure you find any      │
# │  interesting and relevant information given the current year is 2024.        │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: 8ce602c0-8e7a-4db7-a466-54deabd0f1a0
# 🚀 Crew: crew
# └── 📋 Task: 8ce602c0-8e7a-4db7-a466-54deabd0f1a0
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Final Answer:                                                               │
# │  1. **Generative AI Expansion**: In 2024, the adoption of generative AI has  │
# │  accelerated, with AI LLMs becoming integral in various sectors like         │
# │  healthcare, finance, and entertainment, enabling personalized content       │
# │  creation and automated reporting.                                           │
# │                                                                              │
# │  2. **Advancements in Multimodal Capabilities**: AI LLMs in 2024 are         │
# │  increasingly incorporating multimodal functionalities, allowing models to   │
# │  process and generate not only text but also images, audio, and video,       │
# │  enhancing user interaction and application versatility.                     │
# │                                                                              │
# │  3. **Increased Focus on Ethical AI**: The AI community is prioritizing      │
# │  ethics, with LLM developers implementing stronger guidelines to mitigate    │
# │  biases, misinformation, and the unethical generation of harmful content,    │
# │  while promoting transparency in AI outputs.                                 │
# │                                                                              │
# │  4. **Interactive AI Assistants**: The development of more sophisticated     │
# │  interactive AI assistants using LLMs has transformed customer service       │
# │  operations, enabling real-time interactions that feel more natural and      │
# │  human-like, thereby improving user satisfaction.                            │
# │                                                                              │
# │  5. **Consumer Precognition Abilities**: Leveraging LLMs, several companies  │
# │  are exploring anticipatory data analysis that can predict consumer needs    │
# │  and preferences based on previous interactions, leading to more targeted    │
# │  marketing strategies.                                                       │
# │                                                                              │
# │  6. **Customizable LLMs for Businesses**: 2024 has seen the rise of          │
# │  customizable AI LLMs that allow organizations to fine-tune and specialize   │
# │  models for their specific industries or demographics, enhancing their       │
# │  utility and application in personalized tasks.                              │
# │                                                                              │
# │  7. **Enhanced Efficiency through Compression Techniques**: To reduce        │
# │  computational demands and speed up processing times, researchers are        │
# │  investing in state-of-the-art model compression techniques, making LLMs     │
# │  more accessible for smaller businesses and applications.                    │
# │                                                                              │
# │  8. **Improved Collaboration Tools**: The integration of AI LLMs into        │
# │  collaboration tools like Google Docs or Microsoft Teams has streamlined     │
# │  workflows, with AI providing suggestions, automating reports, and           │
# │  assisting in real-time problem-solving.                                     │
# │                                                                              │
# │  9. **Language Diversification Efforts**: Efforts to support                 │
# │  underrepresented languages in LLMs have gained momentum, promoting          │
# │  linguistic diversity and inclusivity by training models on a wider array    │
# │  of languages, dialects, and cultural contexts.                              │
# │                                                                              │
# │  10. **Regulatory Developments**: As the use of AI LLMs expands, 2024 has    │
# │  witnessed significant regulatory frameworks emerging to govern AI use,      │
# │  focusing on user privacy, data protection, and ensuring accountability      │
# │  among AI developers and organizations.                                      │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: 8ce602c0-8e7a-4db7-a466-54deabd0f1a0
#     Assigned to: AI LLMs Senior Data Researcher
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 8ce602c0-8e7a-4db7-a466-54deabd0f1a0                                  │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: 8ce602c0-8e7a-4db7-a466-54deabd0f1a0
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: 8e1b7543-8053-409d-81d7-0ad34ec66564
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Task: Review the context you got and expand each topic into a full section  │
# │  for a report. Make sure the report is detailed and contains any and all     │
# │  relevant information.                                                       │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: 8ce602c0-8e7a-4db7-a466-54deabd0f1a0
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: 8e1b7543-8053-409d-81d7-0ad34ec66564
# 🚀 Crew: crew
# ├── 📋 Task: 8ce602c0-8e7a-4db7-a466-54deabd0f1a0
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: 8e1b7543-8053-409d-81d7-0ad34ec66564
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  # Report on AI LLMs: 2024 Developments and Implications                     │
# │                                                                              │
# │  ## 1. Generative AI Expansion                                               │
# │  In 2024, the landscape of generative AI has witnessed a remarkable          │
# │  acceleration in adoption across various industries. AI-driven Language      │
# │  Learning Models (LLMs) have become integral tools in healthcare, finance,   │
# │  and entertainment sectors, facilitating a range of innovative               │
# │  applications. In healthcare, LLMs are utilized for personalized treatment   │
# │  plans and automating clinical reporting, allowing physicians to focus more  │
# │  on patient care. The finance sector employs generative AI for risk          │
# │  assessment and fraud detection, while in entertainment, these LLMs empower  │
# │  content creators by generating scripts, screenplays, and even music         │
# │  tailored to audience preferences. This expansion not only enhances          │
# │  operational efficiency but also fosters creativity by enabling              │
# │  personalized content creation that resonates deeply with consumers.         │
# │                                                                              │
# │  ## 2. Advancements in Multimodal Capabilities                               │
# │  The capabilities of AI LLMs are rapidly evolving to include multimodal      │
# │  functionalities. In 2024, these advanced models are designed to process     │
# │  and generate diverse forms of media, combining text, images, audio, and     │
# │  video into cohesive outputs. This integration significantly enhances user   │
# │  interaction—users can now engage with AI in varied formats, such as         │
# │  receiving video summaries of reports or interacting through voice commands  │
# │  while receiving visual feedback. Applications range from educational tools  │
# │  that offer both visual and auditory learning aids to marketing platforms    │
# │  that create immersive advertising experiences. The versatility of           │
# │  multimodal LLMs allows for richer user experiences and expands the range    │
# │  of applications across different sectors.                                   │
# │                                                                              │
# │  ## 3. Increased Focus on Ethical AI                                         │
# │  As the deployment of AI LLMs grows, there is a heightened focus within the  │
# │  AI community on ethical considerations surrounding their use. In 2024, LLM  │
# │  developers are actively implementing comprehensive guidelines aimed at      │
# │  mitigating biases inherent in AI systems, curbing the spread of             │
# │  misinformation, and preventing the generation of harmful content.           │
# │  Transparency is emphasized, with initiatives encouraging developers to      │
# │  disclose the data sources and algorithms used in training models. This      │
# │  ethical framework promotes accountability and reinforces public trust in    │
# │  AI technologies responsible for content generation and decision-making      │
# │  processes, thereby fostering a more secure environment for users.           │
# │                                                                              │
# │  ## 4. Interactive AI Assistants                                             │
# │  The sophistication of interactive AI assistants has undergone a notable     │
# │  transformation in 2024, significantly enhancing customer service            │
# │  operations across industries. Leveraging LLMs, these assistants now         │
# │  facilitate real-time interactions that emulate human-like conversations.    │
# │  With the capability to understand context and sentiment, they are adept at  │
# │  handling inquiries, resolving issues, and providing tailored                │
# │  recommendations, improving overall user satisfaction. As organizations      │
# │  integrate these advanced assistants, they not only streamline operations    │
# │  but also enhance customer loyalty by delivering prompt and effective        │
# │  service, marking a significant leap in customer relationship management.    │
# │                                                                              │
# │  ## 5. Consumer Precognition Abilities                                       │
# │  Companies are increasingly harnessing anticipatory data analysis powered    │
# │  by AI LLMs to predict consumer behaviors and preferences based on           │
# │  historical interactions. In 2024, this capability allows businesses to      │
# │  tailor their marketing strategies effectively, presenting consumers with    │
# │  relevant products and services before they consciously express their        │
# │  needs. By analyzing past purchasing patterns and behavioral data,           │
# │  companies can strategize their inventory, improve customer engagement, and  │
# │  ultimately drive sales. This methodology cultivates a more personalized     │
# │  shopping experience, positioning businesses to retain a competitive edge    │
# │  in rapidly evolving markets.                                                │
# │                                                                              │
# │  ## 6. Customizable LLMs for Businesses                                      │
# │  In response to the diverse needs of various sectors, 2024 has seen the      │
# │  emergence of customizable LLMs. These tailored models enable organizations  │
# │  to finetune AI technologies to meet specific industry demands and           │
# │  demographics. Businesses can now adjust model parameters to enhance         │
# │  efficiency in specialized tasks, whether for legal documentation,           │
# │  marketing copy, or technical support. The capability to customize LLMs      │
# │  significantly enhances their application, empowering businesses to          │
# │  leverage AI for unique challenges and improving operational workflows,      │
# │  ultimately leading to innovation in service delivery.                       │
# │                                                                              │
# │  ## 7. Enhanced Efficiency through Compression Techniques                    │
# │  To address the growing computational demands of AI LLMs, significant        │
# │  advancements in model compression techniques are being pursued. In 2024,    │
# │  researchers are actively developing state-of-the-art methods aimed at       │
# │  reducing the computational load and improving processing speeds. This       │
# │  innovation is particularly beneficial for smaller businesses lacking        │
# │  extensive resources, as it makes advanced AI technologies more accessible.  │
# │  Efficient operational performance derived from compressed models allows     │
# │  organizations to implement AI solutions without the need for substantial    │
# │  infrastructure investments, democratizing access to sophisticated AI        │
# │  tools.                                                                      │
# │                                                                              │
# │  ## 8. Improved Collaboration Tools                                          │
# │  The integration of AI LLMs into collaboration tools has reshaped workflows  │
# │  within organizations. In platforms such as Google Docs and Microsoft        │
# │  Teams, LLMs enhance productivity by providing contextual suggestions,       │
# │  automating routine reports, and facilitating real-time problem-solving. In  │
# │  2024, these tools allow teams to collaborate more effectively,              │
# │  streamlining communication and minimizing bottlenecks through intelligent   │
# │  assistance. The capability to offload mundane tasks to AI results in more   │
# │  time for creative and strategic initiatives, ultimately improving overall   │
# │  operational efficiency.                                                     │
# │                                                                              │
# │  ## 9. Language Diversification Efforts                                      │
# │  2024 has marked a pivotal year in efforts to support linguistic diversity   │
# │  and inclusivity within AI LLMs. Recognizing the importance of               │
# │  representation, developers have intensified their efforts to train models   │
# │  on a broader array of languages, dialects, and cultural contexts. This      │
# │  push not only addresses the needs of underrepresented languages but also    │
# │  enhances the ability of AI to serve global markets. By embracing language   │
# │  diversification, organizations can connect with a wider audience,           │
# │  fostering inclusivity and ensuring that AI technology is beneficial to a    │
# │  broader spectrum of users.                                                  │
# │                                                                              │
# │  ## 10. Regulatory Developments                                              │
# │  As the proliferation of AI LLMs continues, 2024 has seen the establishment  │
# │  of significant regulatory frameworks governing their use. These             │
# │  regulations are focused on key areas such as user privacy, data             │
# │  protection, and accountability among AI developers. With governments and    │
# │  organizations recognizing the implications of AI technologies, there is a   │
# │  concerted effort to create standards that ensure responsible usage and      │
# │  transparency. By implementing regulatory measures, stakeholders aim to      │
# │  protect users while enabling innovation, ultimately fostering a balanced    │
# │  ecosystem for AI application in various sectors.                            │
# │                                                                              │
# │  ---                                                                         │
# │  This report captures the comprehensive developments within the AI LLM       │
# │  landscape in 2024, outlining key advancements, ethical considerations, and  │
# │  the transformative impact of these technologies across industries. It       │
# │  serves as a resource for organizations and stakeholders aiming to navigate  │
# │  and leverage the evolving capabilities of AI LLMs effectively.              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: 8ce602c0-8e7a-4db7-a466-54deabd0f1a0
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: 8e1b7543-8053-409d-81d7-0ad34ec66564
#     Assigned to: AI LLMs Reporting Analyst
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 8e1b7543-8053-409d-81d7-0ad34ec66564                                  │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: 60466dc8-9d23-460e-9c97-d38638bacc75                                    │
# │  Tool Args:                                                                  │
# │  Final Output: # Report on AI LLMs: 2024 Developments and Implications       │
# │                                                                              │
# │  ## 1. Generative AI Expansion                                               │
# │  In 2024, the landscape of generative AI has witnessed a remarkable          │
# │  acceleration in adoption across various industries. AI-driven Language      │
# │  Learning Models (LLMs) have become integral tools in healthcare, finance,   │
# │  and entertainment sectors, facilitating a range of innovative               │
# │  applications. In healthcare, LLMs are utilized for personalized treatment   │
# │  plans and automating clinical reporting, allowing physicians to focus more  │
# │  on patient care. The finance sector employs generative AI for risk          │
# │  assessment and fraud detection, while in entertainment, these LLMs empower  │
# │  content creators by generating scripts, screenplays, and even music         │
# │  tailored to audience preferences. This expansion not only enhances          │
# │  operational efficiency but also fosters creativity by enabling              │
# │  personalized content creation that resonates deeply with consumers.         │
# │                                                                              │
# │  ## 2. Advancements in Multimodal Capabilities                               │
# │  The capabilities of AI LLMs are rapidly evolving to include multimodal      │
# │  functionalities. In 2024, these advanced models are designed to process     │
# │  and generate diverse forms of media, combining text, images, audio, and     │
# │  video into cohesive outputs. This integration significantly enhances user   │
# │  interaction—users can now engage with AI in varied formats, such as         │
# │  receiving video summaries of reports or interacting through voice commands  │
# │  while receiving visual feedback. Applications range from educational tools  │
# │  that offer both visual and auditory learning aids to marketing platforms    │
# │  that create immersive advertising experiences. The versatility of           │
# │  multimodal LLMs allows for richer user experiences and expands the range    │
# │  of applications across different sectors.                                   │
# │                                                                              │
# │  ## 3. Increased Focus on Ethical AI                                         │
# │  As the deployment of AI LLMs grows, there is a heightened focus within the  │
# │  AI community on ethical considerations surrounding their use. In 2024, LLM  │
# │  developers are actively implementing comprehensive guidelines aimed at      │
# │  mitigating biases inherent in AI systems, curbing the spread of             │
# │  misinformation, and preventing the generation of harmful content.           │
# │  Transparency is emphasized, with initiatives encouraging developers to      │
# │  disclose the data sources and algorithms used in training models. This      │
# │  ethical framework promotes accountability and reinforces public trust in    │
# │  AI technologies responsible for content generation and decision-making      │
# │  processes, thereby fostering a more secure environment for users.           │
# │                                                                              │
# │  ## 4. Interactive AI Assistants                                             │
# │  The sophistication of interactive AI assistants has undergone a notable     │
# │  transformation in 2024, significantly enhancing customer service            │
# │  operations across industries. Leveraging LLMs, these assistants now         │
# │  facilitate real-time interactions that emulate human-like conversations.    │
# │  With the capability to understand context and sentiment, they are adept at  │
# │  handling inquiries, resolving issues, and providing tailored                │
# │  recommendations, improving overall user satisfaction. As organizations      │
# │  integrate these advanced assistants, they not only streamline operations    │
# │  but also enhance customer loyalty by delivering prompt and effective        │
# │  service, marking a significant leap in customer relationship management.    │
# │                                                                              │
# │  ## 5. Consumer Precognition Abilities                                       │
# │  Companies are increasingly harnessing anticipatory data analysis powered    │
# │  by AI LLMs to predict consumer behaviors and preferences based on           │
# │  historical interactions. In 2024, this capability allows businesses to      │
# │  tailor their marketing strategies effectively, presenting consumers with    │
# │  relevant products and services before they consciously express their        │
# │  needs. By analyzing past purchasing patterns and behavioral data,           │
# │  companies can strategize their inventory, improve customer engagement, and  │
# │  ultimately drive sales. This methodology cultivates a more personalized     │
# │  shopping experience, positioning businesses to retain a competitive edge    │
# │  in rapidly evolving markets.                                                │
# │                                                                              │
# │  ## 6. Customizable LLMs for Businesses                                      │
# │  In response to the diverse needs of various sectors, 2024 has seen the      │
# │  emergence of customizable LLMs. These tailored models enable organizations  │
# │  to finetune AI technologies to meet specific industry demands and           │
# │  demographics. Businesses can now adjust model parameters to enhance         │
# │  efficiency in specialized tasks, whether for legal documentation,           │
# │  marketing copy, or technical support. The capability to customize LLMs      │
# │  significantly enhances their application, empowering businesses to          │
# │  leverage AI for unique challenges and improving operational workflows,      │
# │  ultimately leading to innovation in service delivery.                       │
# │                                                                              │
# │  ## 7. Enhanced Efficiency through Compression Techniques                    │
# │  To address the growing computational demands of AI LLMs, significant        │
# │  advancements in model compression techniques are being pursued. In 2024,    │
# │  researchers are actively developing state-of-the-art methods aimed at       │
# │  reducing the computational load and improving processing speeds. This       │
# │  innovation is particularly beneficial for smaller businesses lacking        │
# │  extensive resources, as it makes advanced AI technologies more accessible.  │
# │  Efficient operational performance derived from compressed models allows     │
# │  organizations to implement AI solutions without the need for substantial    │
# │  infrastructure investments, democratizing access to sophisticated AI        │
# │  tools.                                                                      │
# │                                                                              │
# │  ## 8. Improved Collaboration Tools                                          │
# │  The integration of AI LLMs into collaboration tools has reshaped workflows  │
# │  within organizations. In platforms such as Google Docs and Microsoft        │
# │  Teams, LLMs enhance productivity by providing contextual suggestions,       │
# │  automating routine reports, and facilitating real-time problem-solving. In  │
# │  2024, these tools allow teams to collaborate more effectively,              │
# │  streamlining communication and minimizing bottlenecks through intelligent   │
# │  assistance. The capability to offload mundane tasks to AI results in more   │
# │  time for creative and strategic initiatives, ultimately improving overall   │
# │  operational efficiency.                                                     │
# │                                                                              │
# │  ## 9. Language Diversification Efforts                                      │
# │  2024 has marked a pivotal year in efforts to support linguistic diversity   │
# │  and inclusivity within AI LLMs. Recognizing the importance of               │
# │  representation, developers have intensified their efforts to train models   │
# │  on a broader array of languages, dialects, and cultural contexts. This      │
# │  push not only addresses the needs of underrepresented languages but also    │
# │  enhances the ability of AI to serve global markets. By embracing language   │
# │  diversification, organizations can connect with a wider audience,           │
# │  fostering inclusivity and ensuring that AI technology is beneficial to a    │
# │  broader spectrum of users.                                                  │
# │                                                                              │
# │  ## 10. Regulatory Developments                                              │
# │  As the proliferation of AI LLMs continues, 2024 has seen the establishment  │
# │  of significant regulatory frameworks governing their use. These             │
# │  regulations are focused on key areas such as user privacy, data             │
# │  protection, and accountability among AI developers. With governments and    │
# │  organizations recognizing the implications of AI technologies, there is a   │
# │  concerted effort to create standards that ensure responsible usage and      │
# │  transparency. By implementing regulatory measures, stakeholders aim to      │
# │  protect users while enabling innovation, ultimately fostering a balanced    │
# │  ecosystem for AI application in various sectors.                            │
# │                                                                              │
# │  ---                                                                         │
# │  This report captures the comprehensive developments within the AI LLM       │
# │  landscape in 2024, outlining key advancements, ethical considerations, and  │
# │  the transformative impact of these technologies across industries. It       │
# │  serves as a resource for organizations and stakeholders aiming to navigate  │
# │  and leverage the evolving capabilities of AI LLMs effectively.              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
